# %%
import pandas as pd

# %%
df=pd.read_csv("D:\\Guvi\\Datasets_data\\Airline Quality Ratings.csv")

# %%
df
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 0            1    Male   48    First-time       Business      Business
# 1            2  Female   35     Returning       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   821                2            5.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# ID                                          0
# Gender                                      0
# Age                                         0
# Customer Type                               0
# Type of Travel                              0
# Class                                       0
# Flight Distance                             0
# Departure Delay                             0
# Arrival Delay                             393
# Departure and Arrival Time Convenience      0
# Ease of Online Booking                      0
# Check-in Service                            0
# Online Boarding                             0
# Gate Location                               0
# On-board Service                            0
# Seat Comfort                                0
# Leg Room Service                            0
# Cleanliness                                 0
# Food and Drink                              0
# In-flight Service                           0
# ...

# %%
df['Arrival Delay'].fillna(value=0, inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                                        0
# Gender                                    0
# Age                                       0
# Customer Type                             0
# Type of Travel                            0
# Class                                     0
# Flight Distance                           0
# Departure Delay                           0
# Arrival Delay                             0
# Departure and Arrival Time Convenience    0
# Ease of Online Booking                    0
# Check-in Service                          0
# Online Boarding                           0
# Gate Location                             0
# On-board Service                          0
# Seat Comfort                              0
# Leg Room Service                          0
# Cleanliness                               0
# Food and Drink                            0
# In-flight Service                         0
# In-flight Wifi Service                    0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import pandas as pd

# Assuming df is your DataFrame
# Load your data into df

# Select columns with numeric data types
numeric_cols = df.select_dtypes(include=['float64', 'int64'])

# Optionally, filter based on number of unique values
continuous_cols = [col for col in numeric_cols.columns if df[col].nunique() > 10]  # Adjust threshold as needed

print("Continuous columns:", continuous_cols)
# Out:
# Continuous columns: ['ID', 'Age', 'Flight Distance', 'Departure Delay', 'Arrival Delay']

# %%
import pandas as pd

# Assuming df is your DataFrame
# Load your data into df

# Select columns with object data type (categorical)
categorical_cols = df.select_dtypes(include=['object'])

# Optionally, filter based on number of unique values
# You can adjust the threshold based on your dataset and needs
categorical_cols = [col for col in categorical_cols.columns if df[col].nunique() <= 50]  # Adjust threshold as needed

print("Categorical columns:", categorical_cols)
# Out:
# Categorical columns: ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'Satisfaction']

# %%
Continuous_columns=['ID', 'Age', 'Flight Distance', 'Departure Delay', 'Arrival Delay']
Categorical_columns=['Gender', 'Customer Type', 'Type of Travel', 'Class', 'Satisfaction']

# %%
number_df=df.select_dtypes(include='number')
corr_m=number_df.corr()
corr_m
# Out:
#                                               ID       Age  Flight Distance  \
# ID                                      1.000000  0.020322         0.095504
# Age                                     0.020322  1.000000         0.099459
# Flight Distance                         0.095504  0.099459         1.000000
# Departure Delay                        -0.017643 -0.009041         0.002402
# Arrival Delay                          -0.035405 -0.011206        -0.001973
# Departure and Arrival Time Convenience -0.002192  0.036960        -0.018914
# Ease of Online Booking                  0.013400  0.022565         0.065165
# Check-in Service                        0.079325  0.033475         0.073608
# Online Boarding                         0.055538  0.207572         0.214825
# Gate Location                          -0.000113 -0.000398         0.005520
# On-board Service                        0.055502  0.057078         0.111194
# ...
